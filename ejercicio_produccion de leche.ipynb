# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Datos
años = np.array(list(range(2005, 2020))).reshape(-1, 1)
produccion_leche = np.array([2.3, 4.5, 9, 7.8, 9.12, 10, 10.22, 10.95, 12.3, 12.5, 12.6, 12.77, 13.5, 16.8, 17.2]).reshape(-1, 1)

# Ajuste lineal
modelo = LinearRegression()
modelo.fit(años, produccion_leche)

# Coeficiente de determinación (R^2)
r_cuadrado = modelo.score(años, produccion_leche)
print("Coeficiente de determinación (R^2):", r_cuadrado)

# Predicción para el año 2020
prediccion_2020 = modelo.predict([[2020]])
print("Predicción de producción de leche para el año 2020:", prediccion_2020[0][0])

# Gráfica
plt.figure(figsize=(10, 5))
plt.scatter(años, produccion_leche, color='blue', label='Datos reales')
plt.plot(años, modelo.predict(años), color='red', linestyle='-', label='Ajuste lineal')
plt.title('Producción de leche por año con ajuste lineal')
plt.xlabel('Año')
plt.ylabel('Producción de leche (millones de litros)')
plt.legend()
plt.grid(True)
plt.xticks(range(2005, 2021, 2))
plt.tight_layout()
plt.show()
# Out:
# Coeficiente de determinación (R^2): 0.9011164222224424
# Predicción de producción de leche para el año 2020: 17.57066666666651

# %%
import numpy as np

# Datos
años = np.array(list(range(2005, 2020)))
produccion_leche = np.array([2.3, 4.5, 9, 7.8, 9.12, 10, 10.22, 10.95, 12.3, 12.5, 12.6, 12.77, 13.5, 16.8, 17.2])

# Calcular las sumas necesarias
n = len(años)
sum_x = np.sum(años)
sum_y = np.sum(produccion_leche)
sum_xy = np.sum(años * produccion_leche)
sum_x_squared = np.sum(años**2)

# Calcular la pendiente (m) y la intersección con el eje y (b)
m = (n * sum_xy - sum_x * sum_y) / (n * sum_x_squared - sum_x**2)
b = (sum_y - m * sum_x) / n

# Imprimir la pendiente y la intersección con el eje y
print("Pendiente (m):", m)
print("Intersección con el eje y (b):", b)

# Calcular la ecuación de la línea recta ajustada
print("Ecuación de la línea recta ajustada: y =", m, "x +", b)
# Out:
# Pendiente (m): 0.8500000000002217
# Intersección con el eje y (b): -1699.4293333337794
# Ecuación de la línea recta ajustada: y = 0.8500000000002217 x + -1699.4293333337794

# %%
# Precios
precio_2014 = 11
precio_2015 = 13
precio_2016 = 14
precio_2017 = 20
precio_2018 = 30
precio_2019 = 50

# Índices con respecto al año 2016
indice_2014 = (precio_2014 / precio_2016) * 100
indice_2015 = (precio_2015 / precio_2016) * 100
indice_2016 = (precio_2016 / precio_2016) * 100
indice_2017 = (precio_2017 / precio_2016) * 100
indice_2018 = (precio_2018 / precio_2016) * 100
indice_2019 = (precio_2019 / precio_2016) * 100

# Mostrar los índices
print("Índice en el año 2014:", indice_2014)
print("Índice en el año 2015:", indice_2015)
print("Índice en el año 2016:", indice_2016)
print("Índice en el año 2017:", indice_2017)
print("Índice en el año 2018:", indice_2018)
print("Índice en el año 2019:", indice_2019)
# Out:
# Índice en el año 2014: 78.57142857142857
# Índice en el año 2015: 92.85714285714286
# Índice en el año 2016: 100.0
# Índice en el año 2017: 142.85714285714286
# Índice en el año 2018: 214.28571428571428
# Índice en el año 2019: 357.14285714285717
